# %% [markdown]
# <a href="https://colab.research.google.com/github/OV2294/ATA-NLP/blob/main/NLP_Practical_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# Sample texts

# %%
text1 ="Natural Language Processing is a branch of Artificial Intelligence."
text2 = "NLP is a field of AI that helps computers understand human language."

# %% [markdown]
# Text preprocessing function

# %%
def preprocess(text):
  text=text.lower()
  words = word_tokenize(text)
  stop_words = set(stopwords.words('english'))
  filtered_words = [word for word in words if word.isalnum() and word not in stop_words]
  return " ".join(filtered_words)

# %% [markdown]
# Preprocess the texts

# %%
processed_text1 = preprocess(text1)
processed_text2 = preprocess(text2)

# %% [markdown]
#  TF-IDF Vectorization

# %%
documents = [processed_text1, processed_text2]
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

# %% [markdown]
# Cosine Similarity

# %%
similarity = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:2])

# %% [markdown]
# Output

# %%
print("Preproceeed Text 1: ", processed_text1)
print("Preproceeed Text 2: ", processed_text2)
print("\nCosine Similarity Score: ", similarity[0][0])
# Out:
# Preproceeed Text 1:  natural language processing branch artificial intelligence
# Preproceeed Text 2:  nlp field ai helps computers understand human language
#
# Cosine Similarity Score:  0.07874460345594508
