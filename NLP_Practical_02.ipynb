# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (8.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.2.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 45.9 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
from gensim import corpora
from gensim.models import LdaModel

# %%
docs = [
    ["machine", "learning", "ai"],
    ["deep", "learning", "neural"],
    ["football", "cricket", "sports"]
]

# %%
d = corpora.Dictionary(docs)
corpus = [d.doc2bow(x) for x in docs]

# %%
lda = LdaModel(corpus=corpus, id2word=d, num_topics=2)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy

# %%
print(lda.print_topics())
# Out:
# [(0, '0.203*"learning" + 0.141*"ai" + 0.135*"machine" + 0.116*"cricket" + 0.107*"sports" + 0.102*"neural" + 0.101*"deep" + 0.092*"football"'), (1, '0.147*"football" + 0.146*"learning" + 0.136*"deep" + 0.135*"neural" + 0.129*"sports" + 0.119*"cricket" + 0.097*"machine" + 0.090*"ai"')]
